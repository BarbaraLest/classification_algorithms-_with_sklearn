# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
df = pd.read_csv('./segment-challenge.csv')
df.head()
# Out:
#    id  region-centroid-col  region-centroid-row  region-pixel-count  \
# 0   1                   38                  189                   9
# 1   2                   25                  199                   9
# 2   3                   49                  139                   9
# 3   4                   63                  220                   9
# 4   5                  161                  135                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean   vegde-sd  \
# 0                   0.0                   0.0    1.000000   0.222222
# 1                   0.0                   0.0    1.111110   0.607407
# 2                   0.0                   0.0    0.166667   0.077778
# 3                   0.0                   0.0    3.055560  15.263000
# 4                   0.0                   0.0    0.055556   0.136083
#
#    hedge-mean   hedge-sd  ...  rawred-mean  rawblue-mean  rawgreen-mean  \
# 0    6.222220  33.318500  ...    26.333300      35.22220        25.6667
# 1    1.055560   0.462963  ...    13.111100      17.88890        21.5556
# 2    0.333333   0.088889  ...     0.000000       1.33333         0.0000
# 3    3.666670   6.088890  ...     6.555560       6.44444        11.5556
# 4    0.111111   0.172133  ...     0.777778       3.00000         0.0000
#
#    exred-mean  exblue-mean  exgreen-mean  value-mean  saturation-mean  \
# 0    -8.22222     18.44440     -10.22220    35.22220         0.271208
# 1   -13.22220      1.11111      12.11110    21.55560         0.393002
# 2    -1.33333      2.66667      -1.33333     1.33333         0.777778
# 3    -4.88889     -5.22222      10.11110    11.55560         0.486717
# 4    -1.44444      5.22222      -3.77778     3.00000         1.000000
#
#    hue-mean    class
# 0  -2.04915     path
# 1   2.69011    grass
# 2  -2.09440  foliage
# 3   2.09315    grass
# 4  -1.82221   window
#
# [5 rows x 21 columns]

# %%
df.replace({'cement': '1', 'path': '2',  'grass': '3',  'window': '4', 'foliage':'5','brickface':'6', 'sky': '7'}, inplace = True, regex = True)

# %%
df.head()
# Out:
#    id  region-centroid-col  region-centroid-row  region-pixel-count  \
# 0   1                   38                  189                   9
# 1   2                   25                  199                   9
# 2   3                   49                  139                   9
# 3   4                   63                  220                   9
# 4   5                  161                  135                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean   vegde-sd  \
# 0                   0.0                   0.0    1.000000   0.222222
# 1                   0.0                   0.0    1.111110   0.607407
# 2                   0.0                   0.0    0.166667   0.077778
# 3                   0.0                   0.0    3.055560  15.263000
# 4                   0.0                   0.0    0.055556   0.136083
#
#    hedge-mean   hedge-sd  ...  rawred-mean  rawblue-mean  rawgreen-mean  \
# 0    6.222220  33.318500  ...    26.333300      35.22220        25.6667
# 1    1.055560   0.462963  ...    13.111100      17.88890        21.5556
# 2    0.333333   0.088889  ...     0.000000       1.33333         0.0000
# 3    3.666670   6.088890  ...     6.555560       6.44444        11.5556
# 4    0.111111   0.172133  ...     0.777778       3.00000         0.0000
#
#    exred-mean  exblue-mean  exgreen-mean  value-mean  saturation-mean  \
# 0    -8.22222     18.44440     -10.22220    35.22220         0.271208
# 1   -13.22220      1.11111      12.11110    21.55560         0.393002
# 2    -1.33333      2.66667      -1.33333     1.33333         0.777778
# 3    -4.88889     -5.22222      10.11110    11.55560         0.486717
# 4    -1.44444      5.22222      -3.77778     3.00000         1.000000
#
#    hue-mean  class
# 0  -2.04915      2
# 1   2.69011      3
# 2  -2.09440      5
# 3   2.09315      3
# 4  -1.82221      4
#
# [5 rows x 21 columns]

# %%
x = df.values[:, 1:20]
y = df.values[:, 20]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
clf = svm.SVC(kernel='sigmoid')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
yprediction = clf.predict(X_test)

# %%
print('Resultado previsto:\n', yprediction, '\n')
print('Resultado atual:\n', y_test, '\n')
print('Precisão do modelo de árvore de decisão ID3 para estes dados: ', accuracy_score(y_test, yprediction)*100)
# Out:
# Resultado previsto:
#  ['2' '2' '6' '5' '7' '1' '7' '5' '6' '1' '7' '7' '4' '7' '7' '1' '5' '7'
#  '1' '2' '7' '3' '2' '6' '7' '3' '1' '7' '1' '1' '4' '5' '4' '6' '3' '7'
#  '2' '1' '4' '2' '7' '1' '2' '5' '2' '3' '3' '1' '4' '4' '7' '5' '3' '4'
#  '1' '5' '4' '4' '5' '1' '3' '2' '6' '5' '6' '5' '6' '2' '4' '4' '1' '3'
#  '5' '3' '4' '1' '4' '2' '4' '7' '7' '2' '7' '4' '2' '4' '6' '7' '4' '2'
#  '7' '2' '2' '1' '2' '7' '4' '5' '7' '3' '2' '4' '3' '2' '1' '3' '2' '4'
#  '7' '3' '1' '3' '4' '5' '4' '5' '2' '4' '3' '3' '7' '4' '2' '2' '5' '5'
#  '3' '3' '7' '6' '7' '4' '7' '2' '2' '7' '7' '2' '3' '3' '2' '7' '5' '2'
#  '7' '1' '6' '7' '1' '6' '1' '2' '1' '5' '7' '4' '7' '5' '4' '2' '2' '7'
#  '4' '6' '3' '2' '5' '2' '7' '2' '2' '6' '4' '2' '6' '5' '2' '7' '1' '7'
#  '3' '7' '5' '2' '7' '6' '2' '7' '2' '7' '4' '6' '4' '2' '2' '6' '2' '1'
#  '7' '6' '1' '2' '1' '7' '1' '4' '3' '7' '1' '1' '7' '1' '4' '7' '3' '4'
#  '2' '3' '3' '7' '4' '3' '2' '3' '6' '7' '6' '3' '4' '2' '4' '4' '7' '6'
#  '1' '5' '3' '1' '1' '7' '1' '7' '1' '3' '7' '4' '7' '4' '3' '3' '7' '7'
#  '5' '1' '7' '2' '2' '2' '4' '4' '5' '6' '7' '6' '5' '2' '2' '1' '4' '1'
#  '2' '4' '5' '5' '5' '3' '3' '1' '5' '3' '6' '3' '6' '1' '1' '3' '7' '7'
#  '1' '2' '7' '2' '2' '2' '4' '2' '5' '6' '6' '3' '4' '7' '3' '7' '7' '1'
#  '2' '4' '5' '7' '5' '7' '7' '1' '4' '3' '4' '3' '3' '4' '7' '2' '2' '6'
#  '4' '2' '4' '2' '1' '4' '7' '1' '2' '7' '7' '5' '7' '7' '2' '6' '2' '5'
#  '7' '7' '2' '2' '2' '3' '1' '1' '2' '1' '2' '7' '5' '4' '4' '2' '1' '2'
#  '5' '7' '1' '4' '1' '3' '5' '1' '5' '5' '2' '3' '7' '2' '5' '4' '2' '2'
#  '7' '3' '4' '4' '7' '2' '7' '4' '4' '1' '2' '7' '4' '1' '1' '3' '2' '7'
#  '3' '4' '4' '3' '3' '1' '4' '5' '4' '4' '2' '7' '4' '1' '2' '2' '7' '4'
#  '2' '7' '7' '6' '1' '4' '2' '1' '1' '1' '2' '1' '1' '6' '3' '1' '1' '2'
#  '6' '2' '1' '7' '4' '2' '7' '1' '7' '3' '5' '3' '2' '2' '4' '3' '1' '2']
#
# Resultado atual:
#  ['1' '3' '2' '6' '7' '7' '7' '4' '6' '2' '7' '7' '4' '7' '1' '7' '4' '1'
#  '7' '5' '1' '3' '6' '1' '6' '3' '7' '1' '1' '7' '4' '5' '3' '6' '3' '1'
#  '2' '2' '4' '4' '1' '2' '2' '3' '6' '4' '5' '7' '5' '4' '1' '6' '4' '3'
#  '2' '5' '6' '5' '6' '2' '3' '2' '2' '4' '2' '3' '6' '2' '4' '3' '2' '5'
#  '3' '4' '4' '7' '4' '4' '1' '1' '1' '2' '7' '4' '6' '6' '2' '1' '3' '4'
#  '1' '4' '6' '2' '6' '1' '3' '6' '1' '3' '3' '1' '5' '1' '7' '5' '4' '1'
#  '5' '3' '2' '3' '3' '5' '3' '4' '2' '3' '3' '3' '1' '4' '6' '6' '5' '3'
#  '3' '4' '7' '2' '1' '4' '7' '2' '4' '1' '7' '3' '5' '4' '5' '7' '3' '2'
#  '1' '7' '6' '7' '2' '2' '7' '4' '7' '5' '7' '4' '1' '6' '4' '3' '6' '7'
#  '4' '6' '3' '2' '6' '6' '1' '1' '2' '6' '3' '2' '2' '6' '2' '7' '6' '7'
#  '3' '7' '3' '2' '7' '6' '2' '1' '6' '1' '3' '2' '4' '5' '6' '1' '4' '7'
#  '7' '6' '7' '5' '1' '1' '7' '3' '5' '7' '7' '7' '7' '2' '6' '1' '4' '4'
#  '5' '4' '5' '7' '4' '3' '5' '5' '2' '1' '6' '4' '4' '1' '4' '3' '1' '2'
#  '2' '5' '3' '7' '7' '7' '7' '6' '7' '4' '1' '4' '7' '1' '3' '5' '1' '1'
#  '6' '7' '1' '6' '6' '1' '5' '6' '5' '6' '7' '6' '5' '2' '6' '2' '3' '2'
#  '6' '4' '4' '3' '6' '3' '3' '7' '5' '3' '2' '3' '6' '7' '1' '3' '7' '1'
#  '2' '6' '1' '1' '6' '4' '4' '2' '5' '2' '6' '3' '4' '7' '6' '7' '7' '1'
#  '6' '3' '5' '6' '3' '1' '1' '2' '1' '3' '4' '3' '3' '4' '7' '5' '5' '6'
#  '1' '1' '5' '3' '2' '4' '1' '1' '2' '7' '1' '5' '6' '1' '4' '2' '5' '5'
#  '7' '1' '2' '2' '5' '3' '7' '7' '2' '2' '6' '1' '4' '5' '5' '6' '7' '2'
#  '5' '1' '2' '5' '2' '3' '5' '2' '5' '5' '6' '5' '1' '1' '5' '4' '5' '2'
#  '5' '3' '3' '6' '1' '4' '7' '4' '6' '2' '2' '1' '6' '7' '7' '5' '5' '7'
#  '4' '4' '4' '3' '5' '7' '6' '5' '4' '4' '4' '1' '4' '7' '2' '1' '7' '4'
#  '4' '7' '1' '6' '7' '3' '5' '7' '7' '1' '6' '2' '7' '6' '3' '2' '2' '1'
#  '2' '5' '2' '1' '5' '4' '1' '1' '7' '3' '5' '3' '2' '6' '3' '3' '2' '2']
#
# Precisão do modelo de árvore de decisão ID3 para estes dados:  37.77777777777778
