# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
df = pd.read_csv('./segment-test.csv')
df.head()
# Out:
#    id  region-centroid-col  region-centroid-row  region-pixel-count  \
# 0   1                  144                   35                   9
# 1   2                  118                  180                   9
# 2   3                    6                  174                   9
# 3   4                  152                  220                   9
# 4   5                  189                  142                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean  vegde-sd  \
# 0                   0.0                   0.0    2.333330  2.033060
# 1                   0.0                   0.0    1.944440  1.481990
# 2                   0.0                   0.0    1.888890  1.007410
# 3                   0.0                   0.0    0.944445  0.685185
# 4                   0.0                   0.0    0.000000  0.000000
#
#    hedge-mean  hedge-sd  ...  rawred-mean  rawblue-mean  rawgreen-mean  \
# 0     2.05556   1.73098  ...      32.3333       47.4444        33.0000
# 1     3.11111   1.08866  ...      44.1111       59.0000        42.5556
# 2     2.88889   4.02963  ...      15.1111       17.7778        24.3333
# 3     1.44444   2.16296  ...      11.5556       13.1111        19.2222
# 4     0.00000   0.00000  ...       0.0000        0.0000         0.0000
#
#    exred-mean  exblue-mean  exgreen-mean  value-mean  saturation-mean  \
# 0   -15.77780     29.55560      -13.7778     47.4444         0.319714
# 1   -13.33330     31.33330      -18.0000     59.0000         0.278822
# 2   -11.88890     -3.88889       15.7778     24.3333         0.381867
# 3    -9.22222     -4.55556       13.7778     19.2222         0.416705
# 4     0.00000      0.00000        0.0000      0.0000         0.000000
#
#    hue-mean   class
# 0  -2.13876  cement
# 1  -1.99604    path
# 2   2.39502   grass
# 3   2.30688   grass
# 4   0.00000  window
#
# [5 rows x 21 columns]

# %%
df.replace({'cement': '1', 'path': '2',  'grass': '3',  'window': '4', 'foliage':'5','brickface':'6', 'sky': '7'}, inplace = True, regex = True)

# %%
df.head()
# Out:
#    id  region-centroid-col  region-centroid-row  region-pixel-count  \
# 0   1                  144                   35                   9
# 1   2                  118                  180                   9
# 2   3                    6                  174                   9
# 3   4                  152                  220                   9
# 4   5                  189                  142                   9
#
#    short-line-density-5  short-line-density-2  vedge-mean  vegde-sd  \
# 0                   0.0                   0.0    2.333330  2.033060
# 1                   0.0                   0.0    1.944440  1.481990
# 2                   0.0                   0.0    1.888890  1.007410
# 3                   0.0                   0.0    0.944445  0.685185
# 4                   0.0                   0.0    0.000000  0.000000
#
#    hedge-mean  hedge-sd  ...  rawred-mean  rawblue-mean  rawgreen-mean  \
# 0     2.05556   1.73098  ...      32.3333       47.4444        33.0000
# 1     3.11111   1.08866  ...      44.1111       59.0000        42.5556
# 2     2.88889   4.02963  ...      15.1111       17.7778        24.3333
# 3     1.44444   2.16296  ...      11.5556       13.1111        19.2222
# 4     0.00000   0.00000  ...       0.0000        0.0000         0.0000
#
#    exred-mean  exblue-mean  exgreen-mean  value-mean  saturation-mean  \
# 0   -15.77780     29.55560      -13.7778     47.4444         0.319714
# 1   -13.33330     31.33330      -18.0000     59.0000         0.278822
# 2   -11.88890     -3.88889       15.7778     24.3333         0.381867
# 3    -9.22222     -4.55556       13.7778     19.2222         0.416705
# 4     0.00000      0.00000        0.0000      0.0000         0.000000
#
#    hue-mean  class
# 0  -2.13876      1
# 1  -1.99604      2
# 2   2.39502      3
# 3   2.30688      3
# 4   0.00000      4
#
# [5 rows x 21 columns]

# %%
x = df.values[:, 1:20]
y = df.values[:, 20]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 100)

# %%
clf = svm.SVC()

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
yprediction = clf.predict(X_test)

# %%
print('Resultado previsto:\n', yprediction, '\n')
print('Resultado atual:\n', y_test, '\n')
print('Precisão do modelo de árvore de decisão ID3 para estes dados: ', accuracy_score(y_test, yprediction)*100)
# Out:
# Resultado previsto:
#  ['2' '6' '7' '1' '6' '4' '3' '4' '6' '5' '2' '4' '2' '6' '6' '2' '1' '4'
#  '2' '2' '3' '2' '6' '2' '7' '5' '5' '2' '4' '6' '1' '1' '6' '5' '1' '1'
#  '5' '1' '2' '6' '4' '4' '4' '3' '3' '6' '6' '7' '4' '7' '6' '6' '1' '2'
#  '7' '4' '4' '7' '5' '5' '4' '3' '1' '2' '5' '5' '1' '2' '4' '7' '7' '2'
#  '6' '5' '7' '3' '5' '1' '4' '3' '5' '1' '3' '4' '5' '7' '2' '5' '4' '1'
#  '6' '6' '5' '6' '4' '3' '4' '4' '3' '4' '1' '6' '6' '7' '5' '5' '1' '7'
#  '7' '6' '1' '4' '6' '3' '2' '5' '4' '7' '3' '5' '5' '6' '4' '5' '2' '5'
#  '5' '4' '7' '3' '4' '4' '4' '3' '2' '3' '3' '6' '4' '2' '4' '5' '2' '7'
#  '4' '6' '2' '1' '1' '1' '1' '1' '4' '6' '4' '6' '1' '3' '2' '2' '7' '2'
#  '5' '5' '2' '7' '6' '6' '7' '4' '5' '1' '7' '4' '1' '5' '3' '4' '3' '4'
#  '4' '4' '6' '1' '5' '1' '4' '4' '2' '6' '1' '3' '3' '7' '3' '1' '4' '3'
#  '3' '5' '6' '5' '4' '5' '4' '3' '5' '3' '2' '6' '5' '6' '1' '3' '2' '3'
#  '3' '1' '5' '7' '3' '5' '3' '5' '5' '4' '1' '7' '7' '5' '2' '4' '7' '5'
#  '6' '6' '7' '6' '2' '7' '7' '6' '3']
#
# Resultado atual:
#  ['2' '6' '7' '1' '6' '4' '3' '4' '6' '5' '2' '5' '2' '6' '6' '2' '1' '4'
#  '2' '2' '3' '2' '6' '2' '7' '6' '5' '2' '4' '6' '1' '4' '6' '6' '1' '1'
#  '6' '1' '2' '6' '4' '4' '4' '3' '3' '6' '6' '7' '4' '7' '6' '6' '1' '2'
#  '7' '6' '5' '7' '5' '5' '4' '3' '1' '2' '6' '5' '1' '2' '5' '7' '7' '2'
#  '6' '5' '7' '3' '5' '1' '4' '3' '5' '1' '3' '4' '5' '7' '2' '5' '5' '1'
#  '6' '4' '4' '6' '4' '3' '4' '4' '3' '4' '1' '4' '6' '7' '5' '4' '1' '7'
#  '7' '6' '1' '4' '6' '3' '2' '5' '5' '7' '3' '4' '5' '6' '4' '4' '2' '1'
#  '5' '4' '7' '3' '4' '6' '5' '3' '2' '3' '3' '6' '4' '2' '4' '5' '2' '7'
#  '4' '6' '2' '1' '1' '1' '4' '1' '4' '6' '5' '1' '1' '3' '2' '2' '7' '2'
#  '5' '4' '2' '7' '6' '6' '7' '4' '6' '1' '7' '5' '1' '5' '3' '6' '3' '4'
#  '4' '4' '6' '1' '6' '1' '4' '6' '2' '4' '1' '3' '3' '7' '3' '1' '4' '3'
#  '3' '5' '1' '5' '4' '1' '5' '3' '5' '3' '2' '6' '5' '1' '1' '3' '2' '3'
#  '3' '4' '5' '7' '3' '1' '3' '4' '5' '4' '1' '7' '7' '5' '2' '4' '7' '5'
#  '6' '6' '7' '4' '2' '7' '7' '6' '3']
#
# Precisão do modelo de árvore de decisão ID3 para estes dados:  84.36213991769547
